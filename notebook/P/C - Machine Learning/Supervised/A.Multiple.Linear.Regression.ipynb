# %% [markdown]
# ## Please see Fama French Asset Pricing Notebook. It has the following:
# - Data transformation
# - Fit a multiple linear regression model
# - Analizes model performance and statistics interpretation
# - Risidual analysis
# - Final conclusion
